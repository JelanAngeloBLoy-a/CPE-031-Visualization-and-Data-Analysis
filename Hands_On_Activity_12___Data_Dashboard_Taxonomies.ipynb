# %% [markdown]
# <a href="https://colab.research.google.com/github/JelanAngeloBLoy-a/CPE-031-Visualization-and-Data-Analysis/blob/main/Hands_On_Activity_12___Data_Dashboard_Taxonomies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 12 | Data Dashboard Taxonomies**
#
#
#
#
#
# ---

# %% [markdown]
# Name :Jelan Angelo B. Loy-a <br>
# Course Code and Title :CPE 031- Visualizations and Data Analysis <br>
# Date Submitted :10/11/2025 <br>
# Instructor : Engr. Maria Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to demonstrate students’ ability to design, interpret, and evaluate data dashboards. Students will apply principles of effective data dashboards, understand data update mechanisms, explore user interaction features, and relate dashboards to their organizational functions.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Identify the key principles that make data dashboards effective communication tools.
#
# 2. Explain how data updates, user interaction, and organizational function shape dashboard design.
#
# 3. Build an interactive data dashboard in Python using sample data to visualize multiple business metrics.

# %% [markdown]
# **3. Discussions:**
#
# A data dashboard is a visual interface that displays key information and performance indicators in a concise and interactive manner. Dashboards consolidate multiple data sources to provide users with insights for decision-making and performance tracking.
#
# Principles of Effective Dashboards:
#
# Clarity and Simplicity: Visuals should be easy to read and interpret.
#
# Real-Time or Dynamic Data: Dashboards often pull updated data automatically.
#
# Interactivity: Users should be able to filter, sort, or drill down into specific metrics.
#
# Action-Oriented Insights: The dashboard should guide users toward decisions or next steps.
#
# Taxonomies of Data Dashboards:
#
# Data Updates – Dashboards can show static (snapshot) or dynamic (real-time) data.
#
# User Interaction – Some dashboards allow filtering, searching, and selecting parameters.
#
# Organizational Function – Dashboards can serve strategic, analytical, or operational functions.
#
# For example:
#
# Strategic dashboards help top management monitor KPIs.
#
# Analytical dashboards help analysts explore data trends.
#
# Operational dashboards support real-time monitoring of systems and workflows.

# %% [markdown]
# **4. Procedures:**

# %%
# !pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
# Simulated company performance data
np.random.seed(42)
months = pd.date_range("2024-01-01", periods=12, freq="M")
regions = ["North", "South", "East", "West"]
products = ["Laptop", "Tablet", "Phone"]

data = {
    "Month": np.random.choice(months, 200),
    "Region": np.random.choice(regions, 200),
    "Product": np.random.choice(products, 200),
    "Sales": np.random.randint(5000, 20000, 200),
    "Profit": np.random.randint(500, 5000, 200)
}

df = pd.DataFrame(data)
df.head()
# Out:
# /tmp/ipython-input-3445195635.py:3: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#        Month Region Product  Sales  Profit
# 0 2024-07-31   West  Laptop  15738    4012
# 1 2024-04-30   West  Laptop  13945    1756
# 2 2024-11-30   East  Laptop   7082    3876
# 3 2024-08-31   East   Phone  15966    3986
# 4 2024-05-31  South   Phone  16088    4084

# %%
# Aggregated views
sales_by_region = df.groupby("Region", as_index=False)["Sales"].sum()
sales_by_product = df.groupby("Product", as_index=False)["Sales"].sum()
sales_trend = df.groupby("Month", as_index=False)["Sales"].sum().sort_values("Month")

# Create dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Sales by Region", "Sales by Product", "Monthly Sales Trend", "Profit vs Sales"),
                    specs=[[{"type": "bar"}, {"type": "pie"}],
                           [{"colspan": 2}, None]])

# Add charts
fig.add_trace(go.Bar(x=sales_by_region["Region"], y=sales_by_region["Sales"], name="Region Sales"), row=1, col=1)
fig.add_trace(go.Pie(labels=sales_by_product["Product"], values=sales_by_product["Sales"], name="Product Sales"), row=1, col=2)
fig.add_trace(go.Scatter(x=sales_trend["Month"], y=sales_trend["Sales"], mode="lines+markers", name="Monthly Trend"), row=2, col=1)

fig.update_layout(height=700, width=950, title_text="📊 Interactive Data Dashboard Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35bed0d9-ed43-466c-86d2-28a2e21f52b1" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35bed0d9-ed43-466c-86d2-28a2e21f52b1")) {                    Plotly.newPlot(                        "35bed0d9-ed43-466c-86d2-28a2e21f52b1",                        [{"name":"Region Sales","x":["East","North","South","West"],"y":[532002,536654,541249,825364],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Laptop","Phone","Tablet"],"name":"Product Sales","values":[884318,668481,882470],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"mode":"lines+markers","name":"Monthly Trend","x":["2024-01-31T00:00:00","2024-02-29T00:00:00","2024-03-31T00:00:00","2024-04-30T00:00:00","2024-05-31T00:00:00","2024-06-30T00:00:00","2024-07-31T00:00:00","2024-08-31T00:00:00","2024-09-30T00:00:00","2024-10-31T00:00:00","2024-11-30T00:00:00","2024-12-31T00:00:00"],"y":[184076,144338,227239,164009,179320,106348,279015,200151,225316,234621,152441,338395],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...

# %%
# Interactive dashboard: filterable by product
fig = px.bar(df, x="Region", y="Sales", color="Product", barmode="group",
             title="Interactive Dashboard: Sales by Region and Product",
             hover_data=["Profit"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6b81eb2-c8db-4816-bc13-0ab9b801825a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6b81eb2-c8db-4816-bc13-0ab9b801825a")) {                    Plotly.newPlot(                        "d6b81eb2-c8db-4816-bc13-0ab9b801825a",                        [{"alignmentgroup":"True","customdata":[[4012],[1756],[3876],[1896],[4137],[3203],[1853],[857],[3519],[1167],[4968],[4685],[1039],[4636],[4275],[3279],[2081],[4500],[2133],[2652],[2500],[4678],[2548],[2323],[2581],[3919],[3537],[3778],[1829],[4761],[1858],[3677],[2628],[3972],[3093],[4542],[3447],[780],[1166],[4688],[1171],[3622],[3093],[2468],[2253],[2796],[2761],[3378],[4144],[802],[555],[1025],[2625],[864],[2031],[3586],[1213],[1796],[566],[4507],[2972],[3160],[4014],[4312],[3948],[1812],[2824],[2105],[3063],[2897],[4235],[3090]],"hovertemplate":"Product=Laptop\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Laptop","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Laptop","offsetgroup":"Laptop","orientation":"v","showlegend":true,"textposition":"auto","x":["West","West","East","West","West","North","North","South","West","West","South","South","North","West","North","North","West","West","East","East","East","South","South","West","West","North","East","East","North","West","North","East","West","South","East","West","North","South","West","East","East","East","West","West","South","West","North","East","West","South","West","South","East","North","South","East","North","North","West","North","West","North","East","South","South","South","North","South","West","South","North","East"],"xaxis":"x","y":[15738,13945,7082,17377,13967,14817,5417,8974,8267,5825,12668,14708,12543,5728,16540,16000,10988,8766,10644,15518,10917,5728,6365,12186,19512,18923,16769,16332,10588,6062,7156,12860,10161,11541,10334,9846,16516,6542,11313,18704,16185,14409,15578,16911,18807,14580,15048,14872,12494,8141,8486,6810,7923,15406,16794,9268,9849,14273,14086,17477,5504,6214,12576,18428,5133,7105,11316,9910,18460,16476,17490,14442],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3986],[4084],[3331],[4219],[3245],[3279],[3008],[1424],[4985],[2444],[1297],[2324],[3636],[2693],[1010],[904],[2168],[4136],[1216],[1173],[2665],[1270],[2484],[1577],[888],[3314],[2517],[4844],[2680],[4079],[3531],[4664],[4323],[2406],[1260],[1399],[2387],[3766],[4400],[2786],[4702],[4932],[2555],[3266],[3787],[2575],[625],[2656],[4706],[3239],[2475],[1376],[1960],[3209],[2233],[4017],[3370]],"hovertemplate":"Product=Phone\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Phone","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Phone","offsetgroup":"Phone","orientation":"v","showlegend":true,"textposition":"auto","x":["East","South","North","East","North","North","East","South","East","North","South","North","South","West","West","North","West","West","East","East","South","West","West","West","West","East","West","South","North","East","South","South","South","North","West","North","North","North","East","West","West","West","South","West","North","West","West","West","East","West","East","East","South","South","East","East","South"],"xaxis":"x","y":[15966,16088,13808,16338,5412,12587,12164,13867,7967,6122,10073,7143,11806,12357,19552,9968,17144,13787,5698,12400,13082,9171,15011,5717,9946,13335,16414,15808,10305,9729,14348,12330,11801,11731,12241,7539,18964,6191,6540,6365,13691,9312,6324,15019,10301,9748,18971,15150,15188,6531,5823,10029,8627,17972,6852,16125,16003],"yaxis":"y","type":"bar"},{"alignmentgro ...

# %% [markdown]
# **Task 1:** Principles of Effective Data Dashboards
#
# Create your own version of the dashboard above using a different dataset (e.g., student performance, store sales, or IoT sensor readings).
# Ensure that your dashboard demonstrates:
#
# Clarity and simplicity in layout
#
# Appropriate chart types for your data
#
# Use of color and labels to improve readability

# %%
# Simulated company performance data

months = pd.date_range("2025-01-01", periods=12, freq="M")
regions = ["NCR", "Region I", "Region III", "Calabarzon"]
products = ["Smoothy", "Juice", "Milktea"]

data = {
    "Month": np.random.choice(months, 200),
    "Region": np.random.choice(regions, 200),
    "Product": np.random.choice(products, 200),
    "Sales": np.random.randint(5000, 20000, 200),
    "Profit": np.random.randint(500, 5000, 200)
}

df = pd.DataFrame(data)
df.head()
# Out:
# /tmp/ipython-input-3295587126.py:3: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#        Month      Region  Product  Sales  Profit
# 0 2025-03-31  Calabarzon  Milktea  18654    2436
# 1 2025-11-30  Calabarzon  Milktea   8741    2656
# 2 2025-01-31  Calabarzon    Juice   8052    4307
# 3 2025-06-30  Calabarzon    Juice  11574    1801
# 4 2025-06-30         NCR    Juice   5726    4663

# %%
# Aggregated views
sales_by_region = df.groupby("Region", as_index=False)["Sales"].sum()
sales_by_product = df.groupby("Product", as_index=False)["Sales"].sum()
sales_trend = df.groupby("Month", as_index=False)["Sales"].sum().sort_values("Month")

# Create dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Sales by Region", "Sales by Product", "Monthly Sales Trend", "Profit vs Sales"),
                    specs=[[{"type": "bar"}, {"type": "pie"}],
                           [{"colspan": 2}, None]])

# Add charts
fig.add_trace(go.Bar(x=sales_by_region["Region"], y=sales_by_region["Sales"], name="Region Sales"), row=1, col=1)
fig.add_trace(go.Pie(labels=sales_by_product["Product"], values=sales_by_product["Sales"], name="Product Sales"), row=1, col=2)
fig.add_trace(go.Scatter(x=sales_trend["Month"], y=sales_trend["Sales"], mode="lines+markers", name="Monthly Trend"), row=2, col=1)

fig.update_layout(height=700, width=950, title_text="📊 Summary Sales of Beverages")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97149e52-a48a-4e70-bd62-0bbf93afb408" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97149e52-a48a-4e70-bd62-0bbf93afb408")) {                    Plotly.newPlot(                        "97149e52-a48a-4e70-bd62-0bbf93afb408",                        [{"name":"Region Sales","x":["Calabarzon","NCR","Region I","Region III"],"y":[680907,578277,489277,672078],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Juice","Milktea","Smoothy"],"name":"Product Sales","values":[670636,718413,1031490],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"mode":"lines+markers","name":"Monthly Trend","x":["2025-01-31T00:00:00","2025-02-28T00:00:00","2025-03-31T00:00:00","2025-04-30T00:00:00","2025-05-31T00:00:00","2025-06-30T00:00:00","2025-07-31T00:00:00","2025-08-31T00:00:00","2025-09-30T00:00:00","2025-10-31T00:00:00","2025-11-30T00:00:00","2025-12-31T00:00:00"],"y":[194442,154823,221279,192849,225017,229224,197911,235739,187576,248179,124434,209066],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# **Task 2:** Data Dashboard Taxonomies
#
# Add interactivity features such as:
#
# A dropdown menu to select regions or products
#
# A dynamic update (simulating real-time data) using Python’s update functions
#
# Explain how your dashboard fits into:
#
# Data Update Type (Static, Scheduled, or Real-Time)
#
# User Interaction (Filter, Drilldown, etc.)
#
# Organizational Function (Strategic, Analytical, Operational)

# %%
import time, numpy as np, pandas as pd, plotly.express as px

for i in range(3):
   fig = px.bar(df, x="Region", y="Sales", color="Product", barmode="group",
             title=f"Interactive Dashboard: Sales by Region and ProductSales Update {i+1}",
             hover_data=["Profit"])
   fig.show()
   time.sleep(2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="53c24aeb-be93-4af9-800c-68324e5ec8f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53c24aeb-be93-4af9-800c-68324e5ec8f6")) {                    Plotly.newPlot(                        "53c24aeb-be93-4af9-800c-68324e5ec8f6",                        [{"alignmentgroup":"True","customdata":[[3245],[2091],[1785],[2883],[2216],[4951],[4238],[1325],[3308],[4008],[4241],[4498],[3829],[2047],[2485],[4955],[1507],[4026],[1747],[4402],[2882],[2387],[1765],[1417],[3252],[521],[784],[4247],[3007],[528],[3006],[4053],[3842],[2704],[2323],[3701],[3655],[3593],[4030],[4616],[2355],[3556],[2309],[2755],[1484],[4133],[4399],[3446],[1026],[616],[3268],[773],[2513],[4933],[3996],[2948],[4837],[501],[4544],[2741],[2669],[3541],[2395],[1134],[2425],[3644],[2213],[750],[2554],[1399]],"hovertemplate":"Product=Juice\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Juice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Juice","offsetgroup":"Juice","orientation":"v","showlegend":true,"textposition":"auto","x":["Region III","NCR","Region III","NCR","Calabarzon","Region I","NCR","Region I","Region III","Calabarzon","Region III","Region III","NCR","NCR","Region I","NCR","Region I","Region I","Region I","Region III","Region I","Region III","Region III","Region III","Region I","Calabarzon","Region I","NCR","NCR","NCR","Calabarzon","NCR","NCR","Region I","Calabarzon","Region III","NCR","Calabarzon","NCR","Region III","NCR","NCR","Calabarzon","Calabarzon","NCR","Region I","Region I","Region III","Region III","Region I","Calabarzon","Region III","Calabarzon","Calabarzon","Region III","NCR","Region III","NCR","Region III","Calabarzon","Calabarzon","Region I","Calabarzon","Region I","NCR","Region III","Region III","Region III","NCR","NCR"],"xaxis":"x","y":[8561,5614,12138,19523,9278,12126,13230,11640,16779,5920,12564,17303,14323,13930,5545,16404,18585,8810,19202,12206,18245,13436,18035,5271,6771,14454,5920,13190,17676,15816,13567,11467,13623,19286,9494,13056,12511,14155,15426,9805,19561,12878,10690,18895,14076,5824,15745,19199,8845,6913,7466,15301,12312,19551,15222,6380,14179,6218,11881,18774,14610,14175,19663,8972,10295,14105,13987,10233,14516,7396],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3611],[2496],[862],[3104],[4786],[2969],[3219],[2903],[2512],[794],[3617],[2190],[2564],[1935],[1071],[2584],[1540],[1385],[3691],[2853],[1186],[2928],[1406],[4499],[1953],[3856],[1015],[1386],[3344],[1598],[3396],[4011],[4526],[4679],[1433],[4110],[2107],[1550],[1459],[4973],[3724],[2753],[3844],[4465],[2375],[2263],[1020],[2933],[4667],[4066],[1228],[2543],[4697],[1278],[4262],[1091],[3220],[1435],[3348],[2449],[589],[2209],[1386],[816],[1939],[1215],[4706]],"hovertemplate":"Product=Smoothy\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoothy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Smoothy","offsetgroup":"Smoothy","orientation":"v","showlegend":true,"textposition":"auto","x":["Region I","NCR","Region I","Region I","Region III","NCR","Region III","NCR","Calabarzon","NCR","NCR","Region III","Calabarzon","Region I","Region III","NCR","Calabarzon","Region III","NCR","Region III","Calabarzon","NCR","Region III","Region I","NCR","Region III","NCR","NCR","Calabarzon","Region I","NCR","NCR","Region III","Region III","Region I","Region III","Region I","Region I","NCR","Region I","Calabarzon","NCR","Calabarzon","NCR","Region III","Region III","Region III","Region I","NCR","Region III","NCR","NCR","Region III","Calabarzon","Region II ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="495bd99a-5ce3-4b4c-96ca-9eb4c3191e81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("495bd99a-5ce3-4b4c-96ca-9eb4c3191e81")) {                    Plotly.newPlot(                        "495bd99a-5ce3-4b4c-96ca-9eb4c3191e81",                        [{"alignmentgroup":"True","customdata":[[3245],[2091],[1785],[2883],[2216],[4951],[4238],[1325],[3308],[4008],[4241],[4498],[3829],[2047],[2485],[4955],[1507],[4026],[1747],[4402],[2882],[2387],[1765],[1417],[3252],[521],[784],[4247],[3007],[528],[3006],[4053],[3842],[2704],[2323],[3701],[3655],[3593],[4030],[4616],[2355],[3556],[2309],[2755],[1484],[4133],[4399],[3446],[1026],[616],[3268],[773],[2513],[4933],[3996],[2948],[4837],[501],[4544],[2741],[2669],[3541],[2395],[1134],[2425],[3644],[2213],[750],[2554],[1399]],"hovertemplate":"Product=Juice\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Juice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Juice","offsetgroup":"Juice","orientation":"v","showlegend":true,"textposition":"auto","x":["Region III","NCR","Region III","NCR","Calabarzon","Region I","NCR","Region I","Region III","Calabarzon","Region III","Region III","NCR","NCR","Region I","NCR","Region I","Region I","Region I","Region III","Region I","Region III","Region III","Region III","Region I","Calabarzon","Region I","NCR","NCR","NCR","Calabarzon","NCR","NCR","Region I","Calabarzon","Region III","NCR","Calabarzon","NCR","Region III","NCR","NCR","Calabarzon","Calabarzon","NCR","Region I","Region I","Region III","Region III","Region I","Calabarzon","Region III","Calabarzon","Calabarzon","Region III","NCR","Region III","NCR","Region III","Calabarzon","Calabarzon","Region I","Calabarzon","Region I","NCR","Region III","Region III","Region III","NCR","NCR"],"xaxis":"x","y":[8561,5614,12138,19523,9278,12126,13230,11640,16779,5920,12564,17303,14323,13930,5545,16404,18585,8810,19202,12206,18245,13436,18035,5271,6771,14454,5920,13190,17676,15816,13567,11467,13623,19286,9494,13056,12511,14155,15426,9805,19561,12878,10690,18895,14076,5824,15745,19199,8845,6913,7466,15301,12312,19551,15222,6380,14179,6218,11881,18774,14610,14175,19663,8972,10295,14105,13987,10233,14516,7396],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3611],[2496],[862],[3104],[4786],[2969],[3219],[2903],[2512],[794],[3617],[2190],[2564],[1935],[1071],[2584],[1540],[1385],[3691],[2853],[1186],[2928],[1406],[4499],[1953],[3856],[1015],[1386],[3344],[1598],[3396],[4011],[4526],[4679],[1433],[4110],[2107],[1550],[1459],[4973],[3724],[2753],[3844],[4465],[2375],[2263],[1020],[2933],[4667],[4066],[1228],[2543],[4697],[1278],[4262],[1091],[3220],[1435],[3348],[2449],[589],[2209],[1386],[816],[1939],[1215],[4706]],"hovertemplate":"Product=Smoothy\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoothy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Smoothy","offsetgroup":"Smoothy","orientation":"v","showlegend":true,"textposition":"auto","x":["Region I","NCR","Region I","Region I","Region III","NCR","Region III","NCR","Calabarzon","NCR","NCR","Region III","Calabarzon","Region I","Region III","NCR","Calabarzon","Region III","NCR","Region III","Calabarzon","NCR","Region III","Region I","NCR","Region III","NCR","NCR","Calabarzon","Region I","NCR","NCR","Region III","Region III","Region I","Region III","Region I","Region I","NCR","Region I","Calabarzon","NCR","Calabarzon","NCR","Region III","Region III","Region III","Region I","NCR","Region III","NCR","NCR","Region III","Calabarzon","Region II ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="836710d6-f281-4cc3-98f1-b07e5bd85ccc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("836710d6-f281-4cc3-98f1-b07e5bd85ccc")) {                    Plotly.newPlot(                        "836710d6-f281-4cc3-98f1-b07e5bd85ccc",                        [{"alignmentgroup":"True","customdata":[[3245],[2091],[1785],[2883],[2216],[4951],[4238],[1325],[3308],[4008],[4241],[4498],[3829],[2047],[2485],[4955],[1507],[4026],[1747],[4402],[2882],[2387],[1765],[1417],[3252],[521],[784],[4247],[3007],[528],[3006],[4053],[3842],[2704],[2323],[3701],[3655],[3593],[4030],[4616],[2355],[3556],[2309],[2755],[1484],[4133],[4399],[3446],[1026],[616],[3268],[773],[2513],[4933],[3996],[2948],[4837],[501],[4544],[2741],[2669],[3541],[2395],[1134],[2425],[3644],[2213],[750],[2554],[1399]],"hovertemplate":"Product=Juice\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Juice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Juice","offsetgroup":"Juice","orientation":"v","showlegend":true,"textposition":"auto","x":["Region III","NCR","Region III","NCR","Calabarzon","Region I","NCR","Region I","Region III","Calabarzon","Region III","Region III","NCR","NCR","Region I","NCR","Region I","Region I","Region I","Region III","Region I","Region III","Region III","Region III","Region I","Calabarzon","Region I","NCR","NCR","NCR","Calabarzon","NCR","NCR","Region I","Calabarzon","Region III","NCR","Calabarzon","NCR","Region III","NCR","NCR","Calabarzon","Calabarzon","NCR","Region I","Region I","Region III","Region III","Region I","Calabarzon","Region III","Calabarzon","Calabarzon","Region III","NCR","Region III","NCR","Region III","Calabarzon","Calabarzon","Region I","Calabarzon","Region I","NCR","Region III","Region III","Region III","NCR","NCR"],"xaxis":"x","y":[8561,5614,12138,19523,9278,12126,13230,11640,16779,5920,12564,17303,14323,13930,5545,16404,18585,8810,19202,12206,18245,13436,18035,5271,6771,14454,5920,13190,17676,15816,13567,11467,13623,19286,9494,13056,12511,14155,15426,9805,19561,12878,10690,18895,14076,5824,15745,19199,8845,6913,7466,15301,12312,19551,15222,6380,14179,6218,11881,18774,14610,14175,19663,8972,10295,14105,13987,10233,14516,7396],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3611],[2496],[862],[3104],[4786],[2969],[3219],[2903],[2512],[794],[3617],[2190],[2564],[1935],[1071],[2584],[1540],[1385],[3691],[2853],[1186],[2928],[1406],[4499],[1953],[3856],[1015],[1386],[3344],[1598],[3396],[4011],[4526],[4679],[1433],[4110],[2107],[1550],[1459],[4973],[3724],[2753],[3844],[4465],[2375],[2263],[1020],[2933],[4667],[4066],[1228],[2543],[4697],[1278],[4262],[1091],[3220],[1435],[3348],[2449],[589],[2209],[1386],[816],[1939],[1215],[4706]],"hovertemplate":"Product=Smoothy\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Smoothy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Smoothy","offsetgroup":"Smoothy","orientation":"v","showlegend":true,"textposition":"auto","x":["Region I","NCR","Region I","Region I","Region III","NCR","Region III","NCR","Calabarzon","NCR","NCR","Region III","Calabarzon","Region I","Region III","NCR","Calabarzon","Region III","NCR","Region III","Calabarzon","NCR","Region III","Region I","NCR","Region III","NCR","NCR","Calabarzon","Region I","NCR","NCR","Region III","Region III","Region I","Region III","Region I","Region I","NCR","Region I","Calabarzon","NCR","Calabarzon","NCR","Region III","Region III","Region III","Region I","NCR","Region III","NCR","NCR","Region III","Calabarzon","Region II ...

# %% [markdown]
# Data Update Type  Real-Time- It is important for data to change in real time for data represented to be more accurate and making sure to be more timely. If not real-time it would cause so many missed opportunities to work with so as much much as possible things have to stay present at all times.If updated on a schedule like daily, it would be Scheduled.
#
#
# User Interaction- User can filter out regions or products and only leave the ones they want to see to observe the patterns and the analyze them to now what to focus on
#
#
# Analytical-The dashboard allows decision-makers to observe and analyze patterns from different regions and products.

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# Create a mini dashboard project that tracks student grades or attendance:
#
# 1. Include 3 visualizations (e.g., average grades by subject, attendance by week, and performance trend).
#
# 2. Add at least one interactive feature (dropdown or slider).
#
# 3. Explain how your dashboard helps an instructor or department make data-driven decisions.

# %%
#np.random.seed(42)
weeks = pd.date_range("2025-01-01", periods=5, freq="W")
subjects = ["Math","Science","English","History","Music"]


data = {
    "Subject":subjects,
    "Grade": np.random.randint(50, 100, 5),
    "Week":weeks,
    "Presents":np.random.randint(0, 5, 5),
    "Lates":np.random.randint(0, 5, 5),
    "Absents":np.random.randint(0, 10, 5),
    "Performance":np.random.randint(50, 100, 5),

}



df = pd.DataFrame(data)
df.head()
# Out:
#    Subject  Grade       Week  Presents  Lates  Absents  Performance
# 0     Math     71 2025-01-05         2      0        6           81
# 1  Science     75 2025-01-12         1      4        3           93
# 2  English     52 2025-01-19         3      2        7           67
# 3  History     90 2025-01-26         3      1        6           55
# 4    Music     91 2025-02-02         4      2        4           67

# %%
# Aggregated views
attendance_summary = df[["Presents", "Lates", "Absents"]].sum().reset_index()
attendance_summary.columns = ["Status", "Count"]

sales_by_region = df.groupby("Subject", as_index=False)["Grade"].sum()
sales_by_product = df.groupby("Presents", as_index=False)["Grade"].sum()
sales_trend = df.groupby("Week", as_index=False)["Grade"].sum().sort_values("Week")



# Create dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Average Grades by Subject", "Attendance by Week", "Academic Performance Trends", "Profit vs Sales"),
                    specs=[[{"type": "bar"}, {"type": "pie"}],
                           [{"colspan": 2}, None]])

# Add charts
fig.add_trace(go.Bar(x=sales_by_region["Subject"], y=sales_by_region["Grade"], name="Attendance:"), row=1, col=1)
fig.add_trace(go.Pie(values=attendance_summary["Count"], labels=attendance_summary["Status"], name="Attendance Distribution"), row=1, col=2)
fig.add_trace(go.Scatter(x=sales_trend["Week"], y=sales_trend["Grade"], mode="lines+markers", name="Weekly Trend"), row=2, col=1)

fig.update_layout(height=700, width=950, title_text="📊 Statistics of high-school student's academic performance")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfe0354b-3b93-44ae-b846-3552945af9ae" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfe0354b-3b93-44ae-b846-3552945af9ae")) {                    Plotly.newPlot(                        "cfe0354b-3b93-44ae-b846-3552945af9ae",                        [{"name":"Attendance:","x":["English","History","Math","Music","Science"],"y":[52,90,71,91,75],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Presents","Lates","Absents"],"name":"Attendance Distribution","values":[13,9,26],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"mode":"lines+markers","name":"Weekly Trend","x":["2025-01-05T00:00:00","2025-01-12T00:00:00","2025-01-19T00:00:00","2025-01-26T00:00:00","2025-02-02T00:00:00"],"y":[71,75,52,90,91],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %% [markdown]
# These visual graphs can help the department understand the sitaution of their students, to see their weaknesses,and their strengths to make sure that every student is experiencing effective learning as much as possible in order to prepare them to be educated individuals. It is their job to always improve their student's academic performance. These graphs also help them notice patterns of what causes the results from these data, this will make detecting improvements and declines more effectively and it is much more easier to manage because of it

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# In conclusion I have learned the ability to design, interpret, and evaluate data dashboards. I also applied the principles of effective data dashboards, understand data update mechanisms, explore user interaction features, and relate dashboards to their organizational functions. Presenting your data in a organized and a interactable way is one of the most effective ways in communincating your data to the people, it would decision-makers to analyze data more effectively, it could also help to know on what needs to be focused on and what things are needed to improve

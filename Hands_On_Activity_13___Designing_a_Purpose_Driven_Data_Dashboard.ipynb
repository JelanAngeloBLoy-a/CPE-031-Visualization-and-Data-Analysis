# %% [markdown]
# <a href="https://colab.research.google.com/github/JelanAngeloBLoy-a/CPE-031-Visualization-and-Data-Analysis/blob/main/Hands_On_Activity_13___Designing_a_Purpose_Driven_Data_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 13 | Designing a Purpose-Driven Data Dashboard**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Jelan Angelo B. Loy-a<br>
# Course Code and Title :CPE 031 - Visualizations and Data Analysis <br>
# Date Submitted : 10/11/2025<br>
# Instructor :Engr. Maria Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to demonstrate students’ ability to design purposeful and user-centered data dashboards. Students will analyze the dashboard’s purpose, evaluate user requirements, and apply engineering principles such as clarity, accuracy, and interactivity in creating effective visual designs.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze how a dashboard’s purpose affects its overall design.
#
# 2. Evaluate how well a dashboard meets the needs of its users.
#
# 3. Create an interactive dashboard that applies clarity, accuracy, and usability.

# %% [markdown]
# **3. Discussions:**
#
# A well-designed data dashboard is more than a collection of charts — it’s a purposeful storytelling tool that connects data to decisions.
#
# Understanding the Purpose of the Data Dashboard:
# Every dashboard must have a clear objective — whether it’s to monitor performance, analyze patterns, or inform strategic decisions. The design should align with this goal, focusing only on the most relevant data and metrics.
#
# Considering the Needs of the Data Dashboard’s Users:
# Dashboards should be designed with the user in mind. A manager may need high-level KPIs, while an analyst may need granular, filterable data. Knowing the user’s goals, skills, and workflow ensures that the dashboard supports, rather than overwhelms, their decision-making.
#
# Data Dashboard Engineering:
# Engineering a dashboard involves organizing visual elements efficiently, ensuring smooth interactivity, and maintaining data accuracy. It also includes performance considerations (like handling large datasets), responsive design, and consistent color schemes.

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Step 1: Install and Import Required Libraries

# %%
# !pip install plotly pandas
import pandas as pd
import numpy as np
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Step 2: Create a Sample Dataset
#
# We’ll simulate student performance data to design an academic performance dashboard.

# %%
# Create dataset
np.random.seed(10)
students = [f"Student {i}" for i in range(1, 21)]
subjects = ["Math", "Science", "English", "Programming", "Data Analytics"]

data = {
    "Student": np.random.choice(students, 100),
    "Subject": np.random.choice(subjects, 100),
    "Score": np.random.randint(60, 100, 100),
    "Attendance (%)": np.random.randint(70, 100, 100)
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Student         Subject  Score  Attendance (%)
# 0  Student 10         English     76              99
# 1   Student 5  Data Analytics     71              98
# 2  Student 16         English     99              75
# 3   Student 1         Science     77              85
# 4  Student 18         Science     99              90

# %% [markdown]
# Step 3: Design Dashboard Components

# %%
# Average Score per Subject
fig1 = px.bar(df.groupby("Subject", as_index=False)["Score"].mean(),
              x="Subject", y="Score", title="Average Score per Subject",
              color="Score", color_continuous_scale="Blues")

# Attendance vs. Score Scatter
fig2 = px.scatter(df, x="Attendance (%)", y="Score", color="Subject",
                  title="Attendance vs. Performance", hover_data=["Student"])

# Score Distribution
fig3 = px.box(df, x="Subject", y="Score", title="Score Distribution by Subject",
              color="Subject")

fig1.show()
fig2.show()
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5cd04fd6-2173-4bba-a7c3-1c40e5e861fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cd04fd6-2173-4bba-a7c3-1c40e5e861fe")) {                    Plotly.newPlot(                        "5cd04fd6-2173-4bba-a7c3-1c40e5e861fe",                        [{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Data Analytics","English","Math","Programming","Science"],"xaxis":"x","y":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3cdb3731-1f0f-4439-8643-844917921b24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cdb3731-1f0f-4439-8643-844917921b24")) {                    Plotly.newPlot(                        "3cdb3731-1f0f-4439-8643-844917921b24",                        [{"customdata":[["Student 10"],["Student 16"],["Student 20"],["Student 12"],["Student 12"],["Student 19"],["Student 3"],["Student 16"],["Student 16"],["Student 12"],["Student 16"],["Student 13"],["Student 14"],["Student 2"],["Student 19"],["Student 1"],["Student 15"],["Student 19"],["Student 18"]],"hovertemplate":"Subject=English\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"English","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"English","orientation":"v","showlegend":true,"x":[99,75,87,71,72,94,88,79,96,98,92,84,85,85,73,82,84,80,80],"xaxis":"x","y":[76,99,91,89,65,79,92,62,77,89,67,89,62,72,70,76,84,86,79],"yaxis":"y","type":"scatter"},{"customdata":[["Student 5"],["Student 17"],["Student 11"],["Student 9"],["Student 11"],["Student 18"],["Student 15"],["Student 6"],["Student 5"],["Student 8"],["Student 13"],["Student 13"],["Student 1"],["Student 9"],["Student 19"],["Student 16"],["Student 20"],["Student 18"],["Student 17"],["Student 1"],["Student 10"]],"hovertemplate":"Subject=Data Analytics\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Data Analytics","orientation":"v","showlegend":true,"x":[98,91,83,90,86,76,71,95,85,92,70,77,93,75,88,90,87,76,93,96,93],"xaxis":"x","y":[71,93,65,73,96,63,91,99,80,91,60,88,79,92,98,98,87,60,87,85,93],"yaxis":"y","type":"scatter"},{"customdata":[["Student 1"],["Student 18"],["Student 10"],["Student 15"],["Student 14"],["Student 14"],["Student 16"],["Student 19"],["Student 17"],["Student 8"],["Student 12"],["Student 12"],["Student 13"],["Student 9"],["Student 14"],["Student 7"],["Student 10"],["Student 17"],["Student 15"],["Student 17"]],"hovertemplate":"Subject=Science\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Science","orientation":"v","showlegend":true,"x":[85,90,84,84,75,87,93,91,87,96,72,78,89,94,96,80,95,91,99,81],"xaxis":"x","y":[77,99,75,76,82,95,90,81,92,77,73,92,75,85,90,66,65,67,69,72],"yaxis":"y","type":"scatter"},{"customdata":[["Student 18"],["Student 9"],["Student 1"],["Student 5"],["Student 9"],["Student 14"],["Student 20"],["Student 13"],["Student 14"],["Student 12"],["Student 2"],["Student 19"],["Student 18"],["Student 9"],["Student 11"],["Student 12"],["Student 14"],["Student 17"],["Student 20"],["Student 11"],["Student 10"]],"hovertemplate":"Subject=Math\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eStudent=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Math","orientation":"v","showlegend":true,"x":[90,73,84,90,82,87,93,93,85,85,99,73,74,73,90,75,84,88,94,71,71],"xaxis":"x","y":[71,74,81,63,65,81,69,95,77,70,98,85,60,83,76,94,75,71,92,86,71],"yaxis":"y","type":"scatter"},{"customdata":[["Student 17"],["Student 5"],["Student 16"],["Student 2"],["Student 5"],["Student 18"],["Student 20"],["Student 6"],["Student 2"],["Student 5"],["Student 10"],["Student 8"],["Student 1"],["Student 11"],["Stude ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="94ee82b7-1f94-4129-af22-d686f36979d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94ee82b7-1f94-4129-af22-d686f36979d1")) {                    Plotly.newPlot(                        "94ee82b7-1f94-4129-af22-d686f36979d1",                        [{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"English","marker":{"color":"#636efa"},"name":"English","notched":false,"offsetgroup":"English","orientation":"v","showlegend":true,"x":["English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English","English"],"x0":" ","xaxis":"x","y":[76,99,91,89,65,79,92,62,77,89,67,89,62,72,70,76,84,86,79],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Analytics","marker":{"color":"#EF553B"},"name":"Data Analytics","notched":false,"offsetgroup":"Data Analytics","orientation":"v","showlegend":true,"x":["Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics","Data Analytics"],"x0":" ","xaxis":"x","y":[71,93,65,73,96,63,91,99,80,91,60,88,79,92,98,98,87,60,87,85,93],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science","marker":{"color":"#00cc96"},"name":"Science","notched":false,"offsetgroup":"Science","orientation":"v","showlegend":true,"x":["Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science","Science"],"x0":" ","xaxis":"x","y":[77,99,75,76,82,95,90,81,92,77,73,92,75,85,90,66,65,67,69,72],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Math","marker":{"color":"#ab63fa"},"name":"Math","notched":false,"offsetgroup":"Math","orientation":"v","showlegend":true,"x":["Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math","Math"],"x0":" ","xaxis":"x","y":[71,74,81,63,65,81,69,95,77,70,98,85,60,83,76,94,75,71,92,86,71],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Subject=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Programming","marker":{"color":"#FFA15A"},"name":"Programming","notched":false,"offsetgroup":"Programming","orientation":"v","showlegend":true,"x":["Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming","Programming"],"x0":" ","xaxis":"x","y":[72,83,77,80,66,70,64,79,71,78,60,92,97,82,67,87,65,79,83],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...

# %% [markdown]
# Step 4: Combine into One Interactive Dashboard

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Aggregated data
avg_scores = df.groupby("Subject", as_index=False)["Score"].mean()
avg_attendance = df.groupby("Subject", as_index=False)["Attendance (%)"].mean()

# Dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Average Score per Subject", "Attendance vs. Score",
                                    "Score Distribution", "Average Attendance per Subject"),
                    specs=[[{"type": "bar"}, {"type": "scatter"}],
                           [{"type": "box"}, {"type": "bar"}]])

fig.add_trace(go.Bar(x=avg_scores["Subject"], y=avg_scores["Score"], name="Average Score"), row=1, col=1)
fig.add_trace(go.Scatter(x=df["Attendance (%)"], y=df["Score"], mode="markers", name="Scatter Plot"), row=1, col=2)
fig.add_trace(go.Box(x=df["Subject"], y=df["Score"], name="Score Distribution"), row=2, col=1)
fig.add_trace(go.Bar(x=avg_attendance["Subject"], y=avg_attendance["Attendance (%)"], name="Average Attendance"), row=2, col=2)

fig.update_layout(height=700, width=950, title_text="🎓 Student Performance Dashboard")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61f66625-3712-4e15-a34a-a033264cf60e" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61f66625-3712-4e15-a34a-a033264cf60e")) {                    Plotly.newPlot(                        "61f66625-3712-4e15-a34a-a033264cf60e",                        [{"name":"Average Score","x":["Data Analytics","English","Math","Programming","Science"],"y":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"type":"bar","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Scatter Plot","x":[99,98,75,85,90,91,90,73,84,84,83,90,90,87,71,72,71,71,72,82,82,88,84,83,72,75,94,87,93,87,93,71,80,94,85,85,86,76,93,91,87,96,72,76,71,75,78,99,86,89,95,85,92,73,70,88,94,79,96,96,80,78,98,70,77,93,74,92,84,73,90,85,75,85,73,84,75,95,84,82,72,89,88,88,91,84,94,90,87,76,80,99,93,71,98,96,80,93,81,71],"y":[76,71,99,77,99,93,71,74,75,81,65,73,63,91,72,83,77,89,65,80,65,66,76,70,64,82,79,81,69,95,95,71,78,79,77,70,96,60,90,81,92,77,73,63,91,92,92,98,97,75,99,80,91,85,60,92,85,62,90,77,66,82,89,67,88,79,60,67,89,83,76,62,94,72,70,75,92,65,87,76,65,79,71,98,67,84,92,98,87,60,86,69,87,86,83,85,79,93,72,71],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"name":"Score Distribution","x":["English","Data Analytics","English","Science","Science","Data Analytics","Math","Math","Science","Math","Data Analytics","Data Analytics","Math","English","Programming","Programming","Programming","English","English","Programming","Math","Programming","Science","Programming","Programming","Science","Programming","Math","Math","Science","Math","Programming","Programming","English","Math","Math","Data Analytics","Programming","Science","Science","Science","Science","Science","Data Analytics","Data Analytics","Programming","Science","Math","Programming","Science","Data Analytics","Data Analytics","Data Analytics","Math","Data Analytics","English","Science","English","Science","English","Science","Programming","English","Programming","Data Analytics","Data Analytics","Math","English","English","Math","Math","English","Math","English","English","Math","Data Analytics","Science","Programming","English","Programming","Programming","Math","Data Analytics","Science","English","Math","Data Analytics","Data Analytics","Data Analytics","English","Science","Data Analytics","Math","Programming","Data Analytics","English","Data Analytics","Science","Math"],"y":[76,71,99,77,99,93,71,74,75,81,65,73,63,91,72,83,77,89,65,80,65,66,76,70,64,82,79,81,69,95,95,71,78,79,77,70,96,60,90,81,92,77,73,63,91,92,92,98,97,75,99,80,91,85,60,92,85,62,90,77,66,82,89,67,88,79,60,67,89,83,76,62,94,72,70,75,92,65,87,76,65,79,71,98,67,84,92,98,87,60,86,69,87,86,83,85,79,93,72,71],"type":"box","xaxis":"x3","yaxis":"y3"},{"name":"Average Attendance","x":["Data Analytics","English","Math","Programming","Science"],"y":[85.95238095238095,84.42105263157895,83.52380952380952,79.57894736842105,87.35],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %% [markdown]
# **Task 1:** Define the Purpose
#
# Write a short paragraph (3–5 sentences) describing the purpose of your dashboard.

# %% [markdown]
# The purpose of this dashboard is to evaluate the student's academic habits and their performance to try to understand their behavious and also their condition during school. It ensures to see the progress of how our departments has been effectively teaching our students and to also know the student's interest to the subject itself. This dashboard will let us know what subjects are needed to be improve here to help our students excel in their academic performance.

# %% [markdown]
# **Task 2:** Design for User Needs
#
# Modify the dashboard to meet specific user needs:
#
# If your user is a teacher, highlight underperforming students.
#
# If your user is a student, highlight their personal progress vs. class average.
#
# If your user is a department head, summarize subject-level averages only.

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Aggregated data
avg_scores = df.groupby("Subject", as_index=False)["Score"].mean()
avg_attendance = df.groupby("Subject", as_index=False)["Attendance (%)"].mean()

# Dashboard layout
fig = make_subplots(rows=1, cols=2,
                    subplot_titles=("Average Score per Subject", "Average Attendance per Subject"),
                    specs=[[{"type": "bar"}, {"type": "bar"}]])

fig.add_trace(go.Bar(x=avg_scores["Subject"], y=avg_scores["Score"], name="Average Score"), row=1, col=1)
fig.add_trace(go.Bar(x=avg_attendance["Subject"], y=avg_attendance["Attendance (%)"], name="Average Attendance"), row=1, col=2)

fig.update_layout(height=700, width=950, title_text="🎓 Student Performance Dashboard")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db753536-74d4-4439-9321-58696b8817b3" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db753536-74d4-4439-9321-58696b8817b3")) {                    Plotly.newPlot(                        "db753536-74d4-4439-9321-58696b8817b3",                        [{"name":"Average Score","x":["Data Analytics","English","Math","Programming","Science"],"y":[83.28571428571429,79.15789473684211,77.95238095238095,76.42105263157895,79.9],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Average Attendance","x":["Data Analytics","English","Math","Programming","Science"],"y":[85.95238095238095,84.42105263157895,83.52380952380952,79.57894736842105,87.35],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatte ...

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# Design Your Own Dashboard: “Smart Campus Energy Monitor”
# Create a dashboard that shows the energy usage of different campus areas (e.g., laboratories, offices, classrooms) over time.
#
# 1. Simulate or use sample data (Energy consumption per hour or per day).
#
# 2. Include at least three charts (bar, line, pie).
#
# 3. Ensure your design reflects a clear purpose and target user (e.g., facilities manager).
#
# 4. Write a short explanation of your engineering decisions (why you chose certain colors, layouts, or interactivity).

# %%
# Create dataset
np.random.seed(10)
days = ["Day 1","Day 2", "Day 3", "Day 4", "Day 5", "Day 6", "Day 7"]

data = {
    "Day": days,
    "Energy Consumption": np.random.randint(1000, 2000, 7),
}

df = pd.DataFrame(data)
df.head(7)
# Out:
#      Day  Energy Consumption
# 0  Day 1                1265
# 1  Day 2                1125
# 2  Day 3                1996
# 3  Day 4                1527
# 4  Day 5                1320
# 5  Day 6                1369
# 6  Day 7                1123

# %%
# Aggregated views
sales_by_region = df.groupby("Day", as_index=False)["Energy Consumption"].sum()
sales_by_product = df.groupby("Day", as_index=False)["Energy Consumption"].sum()
sales_trend = df.groupby("Day", as_index=False)["Energy Consumption"].sum().sort_values("Day")

# Create dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Energy consumed per day", "Energy share per day", "Energy trend over the week", "Profit vs Sales"),
                    specs=[[{"type": "bar"}, {"type": "pie"}],
                           [{"colspan": 2}, None]])

# Add charts
fig.add_trace(go.Bar(x=sales_by_region["Day"], y=sales_by_region["Energy Consumption"], name="Energy-Consumned per day",marker=dict(color="#66b3ff")), row=1, col=1)
fig.add_trace(go.Pie(labels=sales_by_product["Day"], values=sales_by_product["Energy Consumption"],sort=False, name="Product Sales",marker=dict(colors=["#2ecc71", "#66b3ff", "#8da0cb", "#fc8d62", "#e74c3c", "#f1c40f", "#1abc9c"]
),), row=1, col=2)
fig.add_trace(go.Scatter(x=sales_trend["Day"], y=sales_trend["Energy Consumption"], mode="lines+markers", name="Monthly Trend",line=dict(color="#ff7f0e", width=3),
    marker=dict(color="#e67e22", size=8)), row=2, col=1)

fig.update_layout(height=700, width=950, title_text="📊 Average Energy-Consumption within a Week")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0af1490d-17f7-4617-be06-692ddcebd30e" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0af1490d-17f7-4617-be06-692ddcebd30e")) {                    Plotly.newPlot(                        "0af1490d-17f7-4617-be06-692ddcebd30e",                        [{"marker":{"color":"#66b3ff"},"name":"Energy-Consumned per day","x":["Day 1","Day 2","Day 3","Day 4","Day 5","Day 6","Day 7"],"y":[1265,1125,1996,1527,1320,1369,1123],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Day 1","Day 2","Day 3","Day 4","Day 5","Day 6","Day 7"],"marker":{"colors":["#2ecc71","#66b3ff","#8da0cb","#fc8d62","#e74c3c","#f1c40f","#1abc9c"]},"name":"Product Sales","sort":false,"values":[1265,1125,1996,1527,1320,1369,1123],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"line":{"color":"#ff7f0e","width":3},"marker":{"color":"#e67e22","size":8},"mode":"lines+markers","name":"Monthly Trend","x":["Day 1","Day 2","Day 3","Day 4","Day 5","Day 6","Day 7"],"y":[1265,1125,1996,1527,1320,1369,1123],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"ou ...

# %% [markdown]
# The light blue color in the bar graph represents stability, trust, and data accuracy, hence it is perfect for monitoring the energy consumption in the bar graph.
#
# In the pie chart the different variety of colors help differentiate each day, which gives them their own identity and it also helped them stand out from the rest, making them easier to be identified and noticed here
#
# In the line graph we use the orange color, warm colors like orange attract the viewers attention which makes it easier for the viewer to followw along the line
#
# The zoom panel helps the facility manager have a closer look on the graphs present and to see their exact value.
# The legend click toggle helps hide or isolate other variables present in the graph which makes it easier for the facility managaer to know on what to focus on
# The download and export lets the facility manager save the graph itself for inclusion in energy reports or maintenance logs.
#
# And the hover tooltips helps show the eaxct values immeadiately instead of taking too much time trying to figure out the exact value by assuming the value depending on the graph

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# A well designed dashboard is very important in the professional world especially when prensenting them to professional people and decision-makers, as it would help them break down and identify patterns that is happening within their industry. Making sure to show a clear data to professionals would be very helpful for them to come up with strategic planning, timely-action and effective planning.
